# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities      = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bar_density = [          8.6,         8.5,     8.3,          7.9,      7.2]

# %%
# Create a bar chart based upon the above data

plt.bar(cities, bar_density, color='blue', alpha=1, align="center")

# Sets the y limits of the current chart
plt.ylim(0.00, 9.00)

# Set chart title and axis labels
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bars Per 10,000 Households")

# Show chart
plt.show()
# Set the limits of the y axis


# Give the chart a title, x label, and y label


# Show chart
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Save an image of the chart
plt.savefig("Image/barchart.png")

# %%
#close the interactive feature so that it doesn't change. 
plt.close()
